# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file = "State_of_California_Geocoded_Providers__2019_California_Clinics_Geocoded.csv"
file_df = pd.read_csv(file)
#file_df.columns
file_df.head(5)
# Out:
#    ID  ReportingDataHistoryTransactionID  FilingProviderNetworkID  \
# 0   1                                 29                    45378
# 1   2                                 29                    45378
# 2   3                                 29                    45378
# 3   4                                 29                    45378
# 4   5                                 29                    45378
#
#   FileNumberID                               LegalName  \
# 0     933 0521  Aetna Better Health of California Inc.
# 1     933 0521  Aetna Better Health of California Inc.
# 2     933 0521  Aetna Better Health of California Inc.
# 3     933 0521  Aetna Better Health of California Inc.
# 4     933 0521  Aetna Better Health of California Inc.
#
#   ReportingForHealthPlanID ReportingByHealthPlanID  \
# 0                      NaN                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# ...

# %%
health_data_pd = file_df.loc[:, ["Latitude", "Longitude", "StandardZip", "ZipClassUSCensus", 
                                 "ClinicServiceType", "CountyName", "LegalName", "ClinicName"]]
health_data_pd.head(25)
# Out:
#       Latitude    Longitude  StandardZip ZipClassUSCensus  \
# 0   38644260.0  121142336.0      95630.0            Urban
# 1   32645967.0  117001688.0      91910.0            Urban
# 2   32819870.0  117179333.0      92111.0            Urban
# 3   32775035.0  117144456.0      92108.0            Urban
# 4   32912885.0  117145760.0      92126.0            Urban
# 5   32838586.0  116968254.0      92071.0            Urban
# 6   32642394.0  117081653.0      91910.0            Urban
# 7   32994999.0  117057776.0      92064.0            Urban
# 8   38645535.0  121477996.0      95834.0            Urban
# 9   33138848.0  117156740.0      92069.0            Urban
# 10  32782690.0  117252299.0      92109.0            Urban
# 11  32746449.0  117198406.0      92110.0            Urban
# 12  33187040.0  116330560.0      92004.0            Rural
# 13  38571080.0  121448523.0      95819.0            Urban
# 14  38423174.0  121412075.0      95758.0            Urban
# ...

# %%
health_data_pd.to_csv("health_data.csv", index=False)
